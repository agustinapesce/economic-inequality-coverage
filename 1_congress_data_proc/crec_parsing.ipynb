# %% [markdown]
# #### Modification of Segun's code

# %%
import os, datetime, json, time
from collections import OrderedDict
import pandas as pd
from xml.etree import ElementTree as ET

# %%
print("Current Directory:", os.getcwd())
# Out:
# Current Directory: c:\Users\agust\Documents\SEDS\SEDS_thesis\1_congress_data_proc\US_Congressional_speeches_EMI

# %%
start_date = '2023-01-04'
end_date   = '2024-12-31'

day        = datetime.datetime.strptime(start_date, '%Y-%m-%d')
end_day    = datetime.datetime.strptime(end_date, '%Y-%m-%d')

DO_SAVE = False 
data = []

# %%
def remove_extra_spaces(s):
    while '  ' in s:
        s = s.replace('  ', ' ')
    return s.strip()

# %%
while day <= end_day:
    cur_date_str  = datetime.datetime.strftime(day, '%Y-%m-%d')
    
    base_dir_xml = os.path.join('.', 'congressional-record', 'output', str(day.year), f'CREC-{cur_date_str}')
    base_dir_json = os.path.join(base_dir_xml, 'json')
    
    if os.path.exists(base_dir_json):

        start_time = time.time()
        
        # Get congress number from XML file
        xmlfile = os.path.join(base_dir_xml, 'mods.xml')
        if not os.path.exists(xmlfile):
            raise Exception('Metadata XML file not found for %s' % base_dir_xml)
        
        xmltree = ET.parse(xmlfile)
        o = xmltree.getroot().find('./{http://www.loc.gov/mods/v3}extension/{http://www.loc.gov/mods/v3}congress')
        congress_num = int(o.text)

        num_speeches = 0
        for fname in os.listdir(base_dir_json):
            if fname.endswith('.xml'):  # read in all xml files
                print(fname)
                
            if fname.endswith('.json'):  # read in all json files
                o=json.load(open(os.path.join(base_dir_json, fname),'r'))
                h=o['header']
                
                if h['chamber'] == 'House':
                    chamber = 'H'
                elif h['chamber'] == 'Senate':
                    chamber = 'S'
                else:
                    raise Exception('Unknown chamber %s' % h['chamber'])
                    
                for ndx, c in enumerate(o['content']):
                    
                    if c['kind']!='speech':
                        continue
                    
                    num_speeches += 1
                                        
                    speaker = c['speaker'].strip()
                    if 'clerk' in speaker:
                        raise Exception('Found a speech by the clerk')
                        
                    text = c['text'].strip()
                    
                    # Remove speaker's name from beginning of speech
                    if text.startswith(speaker + '.'):
                        text = text[len(speaker + '.'):]
                    elif text.startswith(speaker + ' .'):
                        text = text[len(speaker + ' .'):]
                    else:
                        print(speaker+ '/' +text[:100])
                        raise Exception('Text doesn\'t start with speaker name')
                        
                    text = remove_extra_spaces(text.replace('\n',' '))
                    
                    speech_id = '%s-%d' % (o['id'], ndx)
                    
                    # This creates another row that will go into the final dataframe
                    row = OrderedDict(
                        speech_id    = speech_id,
                        speech       = text,
                        chamber      = chamber,
                        is_extension = h['extension'],
                        date         = cur_date_str,
                        speaker      = speaker,
                        speaker_bioguide = c['speaker_bioguide'],
                        vol          = h['vol'],
                        num          = h['num'],
                        congress_num = congress_num,
                        pages        = h['pages'],
                        doc_title    = o['doc_title'],
                        title        = o['title'])
                    data.append(row)
                    
        load_time = time.time() - start_time
        print("Loaded %4d speeches from %s (time: %0.2f s tot, %4.1f ms/speech)" % 
              (num_speeches, cur_date_str, load_time, 1000*load_time/num_speeches if num_speeches > 0 else 0) )
                    
    day += datetime.timedelta(days=1)
# Out:
# Loaded    5 speeches from 2023-01-04 (time: 0.01 s tot,  2.2 ms/speech)
# Loaded   51 speeches from 2023-01-05 (time: 0.01 s tot,  0.2 ms/speech)
# Loaded  270 speeches from 2023-01-09 (time: 0.06 s tot,  0.2 ms/speech)
# Loaded  225 speeches from 2023-01-10 (time: 0.09 s tot,  0.4 ms/speech)
# Loaded  299 speeches from 2023-01-11 (time: 0.04 s tot,  0.1 ms/speech)
# Loaded  151 speeches from 2023-01-12 (time: 0.03 s tot,  0.2 ms/speech)
# Loaded    9 speeches from 2023-01-13 (time: 0.04 s tot,  4.4 ms/speech)
# Loaded   20 speeches from 2023-01-17 (time: 0.03 s tot,  1.6 ms/speech)
# Loaded   19 speeches from 2023-01-20 (time: 0.02 s tot,  1.0 ms/speech)
# Loaded   60 speeches from 2023-01-23 (time: 0.01 s tot,  0.2 ms/speech)
# Loaded  225 speeches from 2023-01-24 (time: 0.04 s tot,  0.2 ms/speech)
# Loaded  335 speeches from 2023-01-25 (time: 0.11 s tot,  0.3 ms/speech)
# Loaded 1187 speeches from 2023-01-26 (time: 0.28 s tot,  0.2 ms/speech)
# Loaded  342 speeches from 2023-01-27 (time: 0.39 s tot,  1.1 ms/speech)
# Loaded  193 speeches from 2023-01-30 (time: 0.06 s tot,  0.3 ms/speech)
# Loaded  398 speeches from 2023-01-31 (time: 0.13 s tot,  0.3 ms/speech)
# Loaded  362 speeches from 2023-02-01 (time: 3.41 s tot,  9.4 ms/speech)
# Loaded  357 speeches from 2023-02-02 (time: 3.52 s tot,  9.9 ms/speech)
# Loaded    2 speeches from 2023-02-03 (time: 0.04 s tot, 21.3 ms/speech)
# Loaded  133 speeches from 2023-02-06 (time: 0.64 s tot,  4.8 ms/speech)
# Loaded  182 speeches from 2023-02-07 (time: 0.88 s tot,  4.8 ms/speech)
# Loaded  264 speeches from 2023-02-08 (time: 0.68 s tot,  2.6 ms/speech)
# Loaded  260 speeches from 2023-02-09 (time: 4.02 s tot, 15.5 ms/speech)
# Loaded   17 speeches from 2023-02-10 (time: 0.28 s tot, 16.4 ms/speech)
# Loaded   96 speeches from 2023-02-13 (time: 0.55 s tot,  5.8 ms/speech)
# Loaded  138 speeches from 2023-02-14 (time: 2.60 s tot, 18.8 ms/speech)
# Loaded  118 speeches from 2023-02-15 (time: 0.54 s tot,  4.6 ms/speech)
# Loaded  141 speeches from 2023-02-16 (time: 0.73 s tot,  5.2 ms/speech)
# Loaded   40 speeches from 2023-02-17 (time: 0.74 s tot, 18.4 ms/speech)
# Loaded   16 speeches from 2023-02-21 (time: 0.52 s tot, 32.7 ms/speech)
# Loaded    2 speeches from 2023-02-23 (time: 0.03 s tot, 14.7 ms/speech)
# Loaded   26 speeches from 2023-02-24 (time: 0.59 s tot, 22.9 ms/speech)
# Loaded  287 speeches from 2023-02-27 (time: 3.27 s tot, 11.4 ms/speech)
# Loaded  414 speeches from 2023-02-28 (time: 2.58 s tot,  6.2 ms/speech)
# Loaded  350 speeches from 2023-03-01 (time: 3.42 s tot,  9.8 ms/speech)
# Loaded  122 speeches from 2023-03-02 (time: 0.53 s tot,  4.4 ms/speech)
# Loaded   16 speeches from 2023-03-03 (time: 0.49 s tot, 30.8 ms/speech)
# Loaded   56 speeches from 2023-03-06 (time: 0.28 s tot,  5.0 ms/speech)
# Loaded  296 speeches from 2023-03-07 (time: 3.31 s tot, 11.2 ms/speech)
# Loaded  554 speeches from 2023-03-08 (time: 2.96 s tot,  5.3 ms/speech)
# Loaded  369 speeches from 2023-03-09 (time: 3.55 s tot,  9.6 ms/speech)
# Loaded  128 speeches from 2023-03-10 (time: 0.71 s tot,  5.5 ms/speech)
# Loaded  120 speeches from 2023-03-14 (time: 2.20 s tot, 18.3 ms/speech)
# Loaded  115 speeches from 2023-03-15 (time: 0.48 s tot,  4.2 ms/speech)
# Loaded   96 speeches from 2023-03-16 (time: 0.42 s tot,  4.3 ms/speech)
# Loaded   35 speeches from 2023-03-17 (time: 0.66 s tot, 18.9 ms/speech)
# Loaded  101 speeches from 2023-03-21 (time: 0.91 s tot,  9.0 ms/speech)
# Loaded  284 speeches from 2023-03-22 (time: 2.87 s tot, 10.1 ms/speech)
# Loaded  615 speeches from 2023-03-23 (time: 2.64 s tot,  4.3 ms/speech)
# Loaded  174 speeches from 2023-03-24 (time: 0.64 s tot,  3.7 ms/speech)
# Loaded  217 speeches from 2023-03-27 (time: 1.09 s tot,  5.0 ms/speech)
# Loaded  482 speeches from 2023-03-28 (time: 1.21 s tot,  2.5 ms/speech)
# Loaded  888 speeches from 2023-03-29 (time: 10.06 s tot, 11.3 ms/speech)
# Loaded  382 speeches from 2023-03-30 (time: 2.94 s tot,  7.7 ms/speech)
# Loaded   20 speeches from 2023-04-03 (time: 0.39 s tot, 19.3 ms/speech)
# Loaded   34 speeches from 2023-04-06 (time: 0.82 s tot, 24.2 ms/speech)
# Loaded   27 speeches from 2023-04-10 (time: 0.51 s tot, 18.9 ms/speech)
# Loaded   26 speeches from 2023-04-13 (time: 0.66 s tot, 25.2 ms/speech)
# Loaded  223 speeches from 2023-04-17 (time: 3.22 s tot, 14.4 ms/speech)
# Loaded  346 speeches from 2023-04-18 (time: 3.08 s tot,  8.9 ms/speech)
# Loaded  430 speeches from 2023-04-19 (time: 2.27 s tot,  5.3 ms/speech)
# Loaded  265 speeches from 2023-04-20 (time: 2.97 s tot, 11.2 ms/speech)
# Loaded    1 speeches from 2023-04-21 (time: 0.03 s tot, 28.1 ms/speech)
# Loaded   12 speeches from 2023-04-24 (time: 0.27 s tot, 22.5 ms/speech)
# Loaded  263 speeches from 2023-04-25 (time: 3.16 s tot, 12.0 ms/speech)
# Loaded  556 speeches from 2023-04-26 (time: 2.83 s tot,  5.1 ms/speech)
# Loaded  203 speeches from 2023-04-27 (time: 3.36 s tot, 16.5 ms/speech)
# Loaded  145 speeches from 2023-04-28 (time: 0.97 s tot,  6.7 ms/speech)
# Loaded   89 speeches from 2023-05-01 (time: 0.49 s tot,  5.5 ms/speech)
# Loaded  131 speeches from 2023-05-02 (time: 2.48 s tot, 18.9 ms/speech)
# Loaded  175 speeches from 2023-05-03 (time: 0.68 s tot,  3.9 ms/speech)
# Loaded  118 speeches from 2023-05-04 (time: 0.71 s tot,  6.0 ms/speech)
# Loaded   46 speeches from 2023-05-05 (time: 1.00 s tot, 21.7 ms/speech)
# Loaded  274 speeches from 2023-05-09 (time: 2.31 s tot,  8.4 ms/speech)
# Loaded  382 speeches from 2023-05-10 (time: 2.79 s tot,  7.3 ms/speech)
# Loaded  488 speeches from 2023-05-11 (time: 3.73 s tot,  7.6 ms/speech)
# Loaded  247 speeches from 2023-05-15 (time: 3.12 s tot, 12.6 ms/speech)
# Loaded  275 speeches from 2023-05-16 (time: 2.46 s tot,  8.9 ms/speech)
# Loaded  442 speeches from 2023-05-17 (time: 3.78 s tot,  8.6 ms/speech)
# Loaded  261 speeches from 2023-05-18 (time: 3.87 s tot, 14.8 ms/speech)
# Loaded    2 speeches from 2023-05-19 (time: 0.03 s tot, 13.5 ms/speech)
# Loaded  240 speeches from 2023-05-22 (time: 0.80 s tot,  3.3 ms/speech)
# Loaded  238 speeches from 2023-05-23 (time: 0.78 s tot,  3.3 ms/speech)
# Loaded  327 speeches from 2023-05-24 (time: 0.94 s tot,  2.9 ms/speech)
# Loaded  219 speeches from 2023-05-25 (time: 3.95 s tot, 18.0 ms/speech)
# Loaded   16 speeches from 2023-05-26 (time: 0.24 s tot, 15.2 ms/speech)
# Loaded    4 speeches from 2023-05-29 (time: 0.08 s tot, 19.5 ms/speech)
# Loaded  169 speeches from 2023-05-30 (time: 0.60 s tot,  3.6 ms/speech)
# Loaded  375 speeches from 2023-05-31 (time: 2.84 s tot,  7.6 ms/speech)
# Loaded  338 speeches from 2023-06-01 (time: 0.88 s tot,  2.6 ms/speech)
# Loaded    2 speeches from 2023-06-02 (time: 0.04 s tot, 21.2 ms/speech)
# Loaded  197 speeches from 2023-06-05 (time: 0.88 s tot,  4.5 ms/speech)
# Loaded  173 speeches from 2023-06-06 (time: 2.48 s tot, 14.4 ms/speech)
# Loaded  183 speeches from 2023-06-07 (time: 2.59 s tot, 14.2 ms/speech)
# Loaded  112 speeches from 2023-06-08 (time: 0.38 s tot,  3.4 ms/speech)
# Loaded   15 speeches from 2023-06-09 (time: 0.55 s tot, 36.4 ms/speech)
# Loaded  202 speeches from 2023-06-12 (time: 1.98 s tot,  9.8 ms/speech)
# Loaded  503 speeches from 2023-06-13 (time: 2.81 s tot,  5.6 ms/speech)
# Loaded  490 speeches from 2023-06-14 (time: 3.18 s tot,  6.5 ms/speech)
# Loaded  235 speeches from 2023-06-15 (time: 3.58 s tot, 15.2 ms/speech)
# Loaded   24 speeches from 2023-06-16 (time: 0.41 s tot, 17.3 ms/speech)
# Loaded  188 speeches from 2023-06-20 (time: 1.30 s tot,  6.9 ms/speech)
# Loaded  613 speeches from 2023-06-21 (time: 3.32 s tot,  5.4 ms/speech)
# Loaded  381 speeches from 2023-06-22 (time: 3.92 s tot, 10.3 ms/speech)
# Loaded  202 speeches from 2023-06-23 (time: 1.34 s tot,  6.6 ms/speech)
# Loaded    2 speeches from 2023-06-26 (time: 0.03 s tot, 14.9 ms/speech)
# Loaded   33 speeches from 2023-06-27 (time: 0.58 s tot, 17.7 ms/speech)
# Loaded    2 speeches from 2023-06-29 (time: 0.03 s tot, 17.5 ms/speech)
# Loaded   32 speeches from 2023-06-30 (time: 0.98 s tot, 30.7 ms/speech)
# Loaded   10 speeches from 2023-07-03 (time: 0.39 s tot, 39.3 ms/speech)
# Loaded   15 speeches from 2023-07-06 (time: 0.90 s tot, 59.8 ms/speech)
# Loaded  121 speeches from 2023-07-10 (time: 1.55 s tot, 12.8 ms/speech)
# Loaded  290 speeches from 2023-07-11 (time: 3.52 s tot, 12.1 ms/speech)
# Loaded  405 speeches from 2023-07-12 (time: 5.51 s tot, 13.6 ms/speech)
# Loaded 1126 speeches from 2023-07-13 (time: 12.00 s tot, 10.7 ms/speech)
# Loaded  187 speeches from 2023-07-14 (time: 0.95 s tot,  5.1 ms/speech)
# Loaded  166 speeches from 2023-07-17 (time: 1.07 s tot,  6.4 ms/speech)
# Loaded  480 speeches from 2023-07-18 (time: 5.41 s tot, 11.3 ms/speech)
# Loaded  795 speeches from 2023-07-19 (time: 3.28 s tot,  4.1 ms/speech)
# Loaded  256 speeches from 2023-07-20 (time: 3.77 s tot, 14.7 ms/speech)
# Loaded    2 speeches from 2023-07-21 (time: 0.04 s tot, 18.6 ms/speech)
# Loaded   15 speeches from 2023-07-24 (time: 0.39 s tot, 25.7 ms/speech)
# Loaded  440 speeches from 2023-07-25 (time: 4.23 s tot,  9.6 ms/speech)
# Loaded  772 speeches from 2023-07-26 (time: 3.76 s tot,  4.9 ms/speech)
# Loaded  652 speeches from 2023-07-27 (time: 5.72 s tot,  8.8 ms/speech)
# Loaded   17 speeches from 2023-07-28 (time: 0.33 s tot, 19.5 ms/speech)
# Loaded   29 speeches from 2023-08-01 (time: 0.54 s tot, 18.7 ms/speech)
# Loaded   24 speeches from 2023-08-04 (time: 0.55 s tot, 22.8 ms/speech)
# Loaded   24 speeches from 2023-08-08 (time: 0.48 s tot, 20.2 ms/speech)
# Loaded   29 speeches from 2023-08-11 (time: 0.63 s tot, 21.6 ms/speech)
# Loaded   27 speeches from 2023-08-15 (time: 0.46 s tot, 17.2 ms/speech)
# Loaded   23 speeches from 2023-08-18 (time: 0.52 s tot, 22.5 ms/speech)
# Loaded   26 speeches from 2023-08-22 (time: 0.48 s tot, 18.3 ms/speech)
# Loaded   34 speeches from 2023-08-25 (time: 0.69 s tot, 20.3 ms/speech)
# Loaded   24 speeches from 2023-08-29 (time: 0.51 s tot, 21.0 ms/speech)
# Loaded   18 speeches from 2023-09-01 (time: 0.38 s tot, 21.1 ms/speech)
# Loaded   84 speeches from 2023-09-05 (time: 1.28 s tot, 15.2 ms/speech)
# Loaded  120 speeches from 2023-09-06 (time: 0.69 s tot,  5.8 ms/speech)
# Loaded  147 speeches from 2023-09-07 (time: 0.92 s tot,  6.2 ms/speech)
# Loaded   22 speeches from 2023-09-08 (time: 0.79 s tot, 36.0 ms/speech)
# Loaded   51 speeches from 2023-09-11 (time: 0.53 s tot, 10.4 ms/speech)
# Loaded  330 speeches from 2023-09-12 (time: 3.85 s tot, 11.7 ms/speech)
# Loaded  275 speeches from 2023-09-13 (time: 3.40 s tot, 12.3 ms/speech)
# Loaded  414 speeches from 2023-09-14 (time: 4.22 s tot, 10.2 ms/speech)
# Loaded  256 speeches from 2023-09-18 (time: 2.94 s tot, 11.5 ms/speech)
# Loaded  229 speeches from 2023-09-19 (time: 2.94 s tot, 12.8 ms/speech)
# Loaded  324 speeches from 2023-09-20 (time: 2.87 s tot,  8.9 ms/speech)
# Loaded  218 speeches from 2023-09-21 (time: 3.06 s tot, 14.0 ms/speech)
# Loaded   27 speeches from 2023-09-22 (time: 0.36 s tot, 13.3 ms/speech)
# Loaded    7 speeches from 2023-09-23 (time: 0.09 s tot, 12.4 ms/speech)
# Loaded  936 speeches from 2023-09-26 (time: 2.59 s tot,  2.8 ms/speech)
# Loaded 1526 speeches from 2023-09-27 (time: 1.39 s tot,  0.9 ms/speech)
# Loaded 1239 speeches from 2023-09-28 (time: 3.09 s tot,  2.5 ms/speech)
# Loaded  401 speeches from 2023-09-29 (time: 3.21 s tot,  8.0 ms/speech)
# Loaded  207 speeches from 2023-09-30 (time: 0.69 s tot,  3.3 ms/speech)
# Loaded  130 speeches from 2023-10-02 (time: 0.63 s tot,  4.9 ms/speech)
# Loaded  276 speeches from 2023-10-03 (time: 2.40 s tot,  8.7 ms/speech)
# Loaded  133 speeches from 2023-10-04 (time: 0.61 s tot,  4.6 ms/speech)
# Loaded   25 speeches from 2023-10-06 (time: 0.49 s tot, 19.8 ms/speech)
# Loaded   23 speeches from 2023-10-10 (time: 0.36 s tot, 15.5 ms/speech)
# Loaded   44 speeches from 2023-10-11 (time: 0.61 s tot, 13.9 ms/speech)
# Loaded   41 speeches from 2023-10-12 (time: 0.63 s tot, 15.3 ms/speech)
# Loaded   54 speeches from 2023-10-13 (time: 0.69 s tot, 12.8 ms/speech)
# Loaded   69 speeches from 2023-10-16 (time: 0.66 s tot,  9.6 ms/speech)
# Loaded  151 speeches from 2023-10-17 (time: 1.23 s tot,  8.2 ms/speech)
# Loaded  173 speeches from 2023-10-18 (time: 1.10 s tot,  6.4 ms/speech)
# Loaded  143 speeches from 2023-10-19 (time: 0.95 s tot,  6.7 ms/speech)
# Loaded   26 speeches from 2023-10-20 (time: 0.40 s tot, 15.3 ms/speech)
# Loaded    2 speeches from 2023-10-23 (time: 0.03 s tot, 16.8 ms/speech)
# Loaded  112 speeches from 2023-10-24 (time: 1.32 s tot, 11.7 ms/speech)
# Loaded  582 speeches from 2023-10-25 (time: 1.31 s tot,  2.2 ms/speech)
# Loaded  671 speeches from 2023-10-26 (time: 2.97 s tot,  4.4 ms/speech)
# Loaded   72 speeches from 2023-10-30 (time: 0.63 s tot,  8.8 ms/speech)
# Loaded  188 speeches from 2023-10-31 (time: 0.71 s tot,  3.8 ms/speech)
# Loaded  718 speeches from 2023-11-01 (time: 3.10 s tot,  4.3 ms/speech)
# Loaded 1354 speeches from 2023-11-02 (time: 2.36 s tot,  1.7 ms/speech)
# Loaded  157 speeches from 2023-11-03 (time: 0.84 s tot,  5.3 ms/speech)
# Loaded  451 speeches from 2023-11-06 (time: 2.33 s tot,  5.2 ms/speech)
# Loaded  903 speeches from 2023-11-07 (time: 3.34 s tot,  3.7 ms/speech)
# Loaded 1177 speeches from 2023-11-08 (time: 2.66 s tot,  2.3 ms/speech)
# Loaded  777 speeches from 2023-11-09 (time: 2.52 s tot,  3.2 ms/speech)
# Loaded  290 speeches from 2023-11-13 (time: 3.22 s tot, 11.1 ms/speech)
# Loaded 1394 speeches from 2023-11-14 (time: 3.00 s tot,  2.2 ms/speech)
# Loaded  419 speeches from 2023-11-15 (time: 2.95 s tot,  7.0 ms/speech)
# Loaded   35 speeches from 2023-11-17 (time: 0.43 s tot, 12.4 ms/speech)
# Loaded   16 speeches from 2023-11-21 (time: 0.40 s tot, 24.7 ms/speech)
# Loaded    5 speeches from 2023-11-24 (time: 0.11 s tot, 21.2 ms/speech)
# Loaded   83 speeches from 2023-11-27 (time: 0.38 s tot,  4.6 ms/speech)
# Loaded  350 speeches from 2023-11-28 (time: 2.64 s tot,  7.5 ms/speech)
# Loaded  415 speeches from 2023-11-29 (time: 2.65 s tot,  6.4 ms/speech)
# Loaded  548 speeches from 2023-11-30 (time: 3.38 s tot,  6.2 ms/speech)
# Loaded  143 speeches from 2023-12-01 (time: 0.75 s tot,  5.3 ms/speech)
# Loaded  241 speeches from 2023-12-04 (time: 0.97 s tot,  4.0 ms/speech)
# Loaded  284 speeches from 2023-12-05 (time: 2.91 s tot, 10.2 ms/speech)
# Loaded  685 speeches from 2023-12-06 (time: 3.78 s tot,  5.5 ms/speech)
# Loaded  239 speeches from 2023-12-07 (time: 2.78 s tot, 11.6 ms/speech)
# Loaded  389 speeches from 2023-12-11 (time: 2.81 s tot,  7.2 ms/speech)
# Loaded  320 speeches from 2023-12-12 (time: 3.02 s tot,  9.4 ms/speech)
# Loaded  621 speeches from 2023-12-13 (time: 3.69 s tot,  5.9 ms/speech)
# Loaded  431 speeches from 2023-12-14 (time: 3.93 s tot,  9.1 ms/speech)
# Loaded   34 speeches from 2023-12-15 (time: 0.33 s tot,  9.8 ms/speech)
# Loaded  107 speeches from 2023-12-18 (time: 0.39 s tot,  3.7 ms/speech)
# Loaded  215 speeches from 2023-12-19 (time: 2.97 s tot, 13.8 ms/speech)
# Loaded   50 speeches from 2023-12-20 (time: 0.26 s tot,  5.2 ms/speech)
# Loaded   36 speeches from 2023-12-22 (time: 0.50 s tot, 13.8 ms/speech)
# Loaded    6 speeches from 2023-12-26 (time: 0.08 s tot, 13.7 ms/speech)
# Loaded    7 speeches from 2023-12-29 (time: 0.12 s tot, 17.0 ms/speech)
# Loaded    8 speeches from 2024-01-02 (time: 0.14 s tot, 17.0 ms/speech)
# Loaded   20 speeches from 2024-01-05 (time: 0.16 s tot,  7.8 ms/speech)
# Loaded   48 speeches from 2024-01-08 (time: 0.26 s tot,  5.4 ms/speech)
# Loaded  155 speeches from 2024-01-09 (time: 0.86 s tot,  5.5 ms/speech)
# Loaded  362 speeches from 2024-01-10 (time: 2.73 s tot,  7.5 ms/speech)
# Loaded  460 speeches from 2024-01-11 (time: 3.21 s tot,  7.0 ms/speech)
# Loaded  129 speeches from 2024-01-12 (time: 0.46 s tot,  3.6 ms/speech)
# Loaded  196 speeches from 2024-01-16 (time: 0.58 s tot,  2.9 ms/speech)
# Loaded  349 speeches from 2024-01-17 (time: 2.73 s tot,  7.8 ms/speech)
# Loaded  462 speeches from 2024-01-18 (time: 3.34 s tot,  7.2 ms/speech)
# Loaded   86 speeches from 2024-01-22 (time: 0.60 s tot,  7.0 ms/speech)
# Loaded  117 speeches from 2024-01-23 (time: 0.44 s tot,  3.8 ms/speech)
# Loaded   81 speeches from 2024-01-24 (time: 0.52 s tot,  6.4 ms/speech)
# Loaded  148 speeches from 2024-01-25 (time: 1.74 s tot, 11.7 ms/speech)
# Loaded    2 speeches from 2024-01-26 (time: 0.05 s tot, 26.8 ms/speech)
# Loaded  179 speeches from 2024-01-29 (time: 1.24 s tot,  6.9 ms/speech)
# Loaded  272 speeches from 2024-01-30 (time: 2.88 s tot, 10.6 ms/speech)
# Loaded  440 speeches from 2024-01-31 (time: 2.91 s tot,  6.6 ms/speech)
# Loaded  204 speeches from 2024-02-01 (time: 0.91 s tot,  4.5 ms/speech)
# Loaded  304 speeches from 2024-02-05 (time: 2.45 s tot,  8.1 ms/speech)
# Loaded  473 speeches from 2024-02-06 (time: 1.80 s tot,  3.8 ms/speech)
# Loaded  223 speeches from 2024-02-07 (time: 2.30 s tot, 10.3 ms/speech)
# Loaded  145 speeches from 2024-02-08 (time: 0.72 s tot,  5.0 ms/speech)
# Loaded  136 speeches from 2024-02-09 (time: 3.32 s tot, 24.4 ms/speech)
# Loaded   48 speeches from 2024-02-10 (time: 0.19 s tot,  4.0 ms/speech)
# Loaded   83 speeches from 2024-02-11 (time: 0.21 s tot,  2.5 ms/speech)
# Loaded  211 speeches from 2024-02-12 (time: 0.35 s tot,  1.6 ms/speech)
# Loaded  197 speeches from 2024-02-13 (time: 1.08 s tot,  5.5 ms/speech)
# Loaded  257 speeches from 2024-02-14 (time: 1.04 s tot,  4.1 ms/speech)
# Loaded  209 speeches from 2024-02-15 (time: 1.58 s tot,  7.5 ms/speech)
# Loaded   14 speeches from 2024-02-16 (time: 0.30 s tot, 21.6 ms/speech)
# Loaded   19 speeches from 2024-02-20 (time: 0.53 s tot, 27.8 ms/speech)
# Loaded   39 speeches from 2024-02-23 (time: 0.64 s tot, 16.3 ms/speech)
# Loaded   74 speeches from 2024-02-26 (time: 0.72 s tot,  9.7 ms/speech)
# Loaded   96 speeches from 2024-02-27 (time: 0.77 s tot,  8.0 ms/speech)
# Loaded  389 speeches from 2024-02-28 (time: 3.14 s tot,  8.1 ms/speech)
# Loaded  448 speeches from 2024-02-29 (time: 3.52 s tot,  7.9 ms/speech)
# Loaded   13 speeches from 2024-03-01 (time: 0.27 s tot, 20.6 ms/speech)
# Loaded  366 speeches from 2024-03-05 (time: 4.10 s tot, 11.2 ms/speech)
# Loaded  494 speeches from 2024-03-06 (time: 2.57 s tot,  5.2 ms/speech)
# Loaded  294 speeches from 2024-03-07 (time: 3.19 s tot, 10.9 ms/speech)
# Loaded  348 speeches from 2024-03-08 (time: 0.73 s tot,  2.1 ms/speech)
# Loaded  276 speeches from 2024-03-11 (time: 2.35 s tot,  8.5 ms/speech)
# Loaded  488 speeches from 2024-03-12 (time: 2.92 s tot,  6.0 ms/speech)
# Loaded  133 speeches from 2024-03-13 (time: 0.87 s tot,  6.6 ms/speech)
# Loaded  128 speeches from 2024-03-14 (time: 0.54 s tot,  4.2 ms/speech)
# Loaded   18 speeches from 2024-03-15 (time: 0.43 s tot, 24.0 ms/speech)
# Loaded  315 speeches from 2024-03-19 (time: 3.10 s tot,  9.9 ms/speech)
# Loaded  370 speeches from 2024-03-20 (time: 2.94 s tot,  8.0 ms/speech)
# Loaded  484 speeches from 2024-03-21 (time: 3.86 s tot,  8.0 ms/speech)
# Loaded  541 speeches from 2024-03-22 (time: 3.49 s tot,  6.4 ms/speech)
# Loaded   12 speeches from 2024-03-26 (time: 0.30 s tot, 24.9 ms/speech)
# Loaded    2 speeches from 2024-03-28 (time: 0.05 s tot, 26.6 ms/speech)
# Loaded   39 speeches from 2024-03-29 (time: 0.49 s tot, 12.5 ms/speech)
# Loaded    2 speeches from 2024-04-01 (time: 0.03 s tot, 16.1 ms/speech)
# Loaded   14 speeches from 2024-04-02 (time: 0.28 s tot, 20.1 ms/speech)
# Loaded    2 speeches from 2024-04-04 (time: 0.04 s tot, 17.7 ms/speech)
# Loaded   19 speeches from 2024-04-05 (time: 0.39 s tot, 20.6 ms/speech)
# Loaded   73 speeches from 2024-04-08 (time: 0.54 s tot,  7.4 ms/speech)
# Loaded  449 speeches from 2024-04-09 (time: 3.43 s tot,  7.6 ms/speech)
# Loaded  333 speeches from 2024-04-10 (time: 2.05 s tot,  6.2 ms/speech)
# Loaded  169 speeches from 2024-04-11 (time: 2.40 s tot, 14.2 ms/speech)
# Loaded  334 speeches from 2024-04-12 (time: 0.55 s tot,  1.6 ms/speech)
# Loaded  364 speeches from 2024-04-16 (time: 2.17 s tot,  6.0 ms/speech)
# Loaded  496 speeches from 2024-04-17 (time: 2.05 s tot,  4.1 ms/speech)
# Loaded  219 speeches from 2024-04-18 (time: 1.35 s tot,  6.2 ms/speech)
# Loaded  326 speeches from 2024-04-19 (time: 1.11 s tot,  3.4 ms/speech)
# Loaded  336 speeches from 2024-04-20 (time: 0.72 s tot,  2.1 ms/speech)
# Loaded  237 speeches from 2024-04-23 (time: 2.40 s tot, 10.1 ms/speech)
# Loaded   48 speeches from 2024-04-26 (time: 0.55 s tot, 11.5 ms/speech)
# Loaded  346 speeches from 2024-04-29 (time: 0.82 s tot,  2.4 ms/speech)
# Loaded  468 speeches from 2024-04-30 (time: 2.85 s tot,  6.1 ms/speech)
# Loaded  511 speeches from 2024-05-01 (time: 6.57 s tot, 12.9 ms/speech)
# Loaded  122 speeches from 2024-05-02 (time: 3.78 s tot, 31.0 ms/speech)
# Loaded    2 speeches from 2024-05-03 (time: 0.06 s tot, 30.8 ms/speech)
# Loaded  288 speeches from 2024-05-06 (time: 1.84 s tot,  6.4 ms/speech)
# Loaded  404 speeches from 2024-05-07 (time: 4.50 s tot, 11.1 ms/speech)
# Loaded  457 speeches from 2024-05-08 (time: 5.61 s tot, 12.3 ms/speech)
# Loaded  167 speeches from 2024-05-09 (time: 1.25 s tot,  7.5 ms/speech)
# Loaded   45 speeches from 2024-05-10 (time: 1.65 s tot, 36.8 ms/speech)
# Loaded  490 speeches from 2024-05-14 (time: 4.66 s tot,  9.5 ms/speech)
# Loaded  504 speeches from 2024-05-15 (time: 3.90 s tot,  7.7 ms/speech)
# Loaded  473 speeches from 2024-05-16 (time: 3.10 s tot,  6.6 ms/speech)
# Loaded  109 speeches from 2024-05-17 (time: 0.66 s tot,  6.0 ms/speech)
# Loaded   76 speeches from 2024-05-20 (time: 0.36 s tot,  4.8 ms/speech)
# Loaded  353 speeches from 2024-05-21 (time: 2.88 s tot,  8.2 ms/speech)
# Loaded  595 speeches from 2024-05-22 (time: 2.70 s tot,  4.5 ms/speech)
# Loaded  481 speeches from 2024-05-23 (time: 3.38 s tot,  7.0 ms/speech)
# Loaded   15 speeches from 2024-05-24 (time: 0.21 s tot, 14.1 ms/speech)
# Loaded   20 speeches from 2024-05-28 (time: 0.31 s tot, 15.7 ms/speech)
# Loaded   28 speeches from 2024-05-31 (time: 0.32 s tot, 11.4 ms/speech)
# Loaded  430 speeches from 2024-06-03 (time: 1.71 s tot,  4.0 ms/speech)
# Loaded  723 speeches from 2024-06-04 (time: 2.63 s tot,  3.6 ms/speech)
# Loaded  315 speeches from 2024-06-05 (time: 2.40 s tot,  7.6 ms/speech)
# Loaded   31 speeches from 2024-06-07 (time: 0.44 s tot, 14.2 ms/speech)
# Loaded  341 speeches from 2024-06-11 (time: 2.42 s tot,  7.1 ms/speech)
# Loaded  622 speeches from 2024-06-12 (time: 2.40 s tot,  3.9 ms/speech)
# Loaded  691 speeches from 2024-06-13 (time: 2.44 s tot,  3.5 ms/speech)
# Loaded  186 speeches from 2024-06-14 (time: 0.88 s tot,  4.7 ms/speech)
# Loaded   89 speeches from 2024-06-17 (time: 0.58 s tot,  6.6 ms/speech)
# Loaded  182 speeches from 2024-06-18 (time: 1.17 s tot,  6.4 ms/speech)
# Loaded  134 speeches from 2024-06-20 (time: 0.71 s tot,  5.3 ms/speech)
# Loaded   26 speeches from 2024-06-21 (time: 0.51 s tot, 19.7 ms/speech)
# Loaded  200 speeches from 2024-06-25 (time: 1.57 s tot,  7.9 ms/speech)
# Loaded  919 speeches from 2024-06-26 (time: 1.08 s tot,  1.2 ms/speech)
# Loaded  615 speeches from 2024-06-27 (time: 1.94 s tot,  3.2 ms/speech)
# Loaded  194 speeches from 2024-06-28 (time: 1.36 s tot,  7.0 ms/speech)
# Loaded   17 speeches from 2024-07-02 (time: 0.60 s tot, 35.3 ms/speech)
# Loaded   10 speeches from 2024-07-05 (time: 0.33 s tot, 33.4 ms/speech)
# Loaded  220 speeches from 2024-07-08 (time: 2.79 s tot, 12.7 ms/speech)
# Loaded  373 speeches from 2024-07-09 (time: 4.21 s tot, 11.3 ms/speech)
# Loaded  571 speeches from 2024-07-10 (time: 6.75 s tot, 11.8 ms/speech)
# Loaded  344 speeches from 2024-07-11 (time: 12.93 s tot, 37.6 ms/speech)
# Loaded   46 speeches from 2024-07-15 (time: 0.56 s tot, 12.1 ms/speech)
# Loaded   26 speeches from 2024-07-18 (time: 0.45 s tot, 17.3 ms/speech)
# Loaded  382 speeches from 2024-07-22 (time: 0.71 s tot,  1.9 ms/speech)
# Loaded 1221 speeches from 2024-07-23 (time: 4.96 s tot,  4.1 ms/speech)
# Loaded  611 speeches from 2024-07-24 (time: 6.56 s tot, 10.7 ms/speech)
# Loaded  288 speeches from 2024-07-25 (time: 3.84 s tot, 13.3 ms/speech)
# Loaded    9 speeches from 2024-07-26 (time: 0.17 s tot, 18.5 ms/speech)
# Loaded   92 speeches from 2024-07-29 (time: 0.72 s tot,  7.8 ms/speech)
# Loaded  159 speeches from 2024-07-30 (time: 2.83 s tot, 17.8 ms/speech)
# Loaded  172 speeches from 2024-07-31 (time: 0.72 s tot,  4.2 ms/speech)
# Loaded  169 speeches from 2024-08-01 (time: 1.37 s tot,  8.1 ms/speech)
# Loaded   33 speeches from 2024-08-02 (time: 1.23 s tot, 37.2 ms/speech)
# Loaded   31 speeches from 2024-08-06 (time: 0.58 s tot, 18.8 ms/speech)
# Loaded   30 speeches from 2024-08-09 (time: 0.54 s tot, 18.0 ms/speech)
# Loaded   17 speeches from 2024-08-13 (time: 0.33 s tot, 19.2 ms/speech)
# Loaded   34 speeches from 2024-08-16 (time: 0.63 s tot, 18.4 ms/speech)
# Loaded   36 speeches from 2024-08-20 (time: 0.46 s tot, 12.9 ms/speech)
# Loaded   14 speeches from 2024-08-23 (time: 0.35 s tot, 25.0 ms/speech)
# Loaded   31 speeches from 2024-08-27 (time: 0.47 s tot, 15.1 ms/speech)
# Loaded   23 speeches from 2024-08-30 (time: 0.52 s tot, 22.8 ms/speech)
# Loaded   17 speeches from 2024-09-03 (time: 0.31 s tot, 18.3 ms/speech)
# Loaded    2 speeches from 2024-09-05 (time: 0.04 s tot, 22.1 ms/speech)
# Loaded   22 speeches from 2024-09-06 (time: 0.66 s tot, 30.0 ms/speech)
# Loaded  480 speeches from 2024-09-09 (time: 2.80 s tot,  5.8 ms/speech)
# Loaded  534 speeches from 2024-09-10 (time: 3.46 s tot,  6.5 ms/speech)
# Loaded  399 speeches from 2024-09-11 (time: 3.67 s tot,  9.2 ms/speech)
# Loaded  209 speeches from 2024-09-12 (time: 2.65 s tot, 12.7 ms/speech)
# Loaded  105 speeches from 2024-09-16 (time: 0.81 s tot,  7.8 ms/speech)
# Loaded  728 speeches from 2024-09-17 (time: 2.96 s tot,  4.1 ms/speech)
# Loaded  507 speeches from 2024-09-18 (time: 2.85 s tot,  5.6 ms/speech)
# Loaded  575 speeches from 2024-09-19 (time: 2.88 s tot,  5.0 ms/speech)
# Loaded  176 speeches from 2024-09-20 (time: 1.28 s tot,  7.3 ms/speech)
# Loaded  553 speeches from 2024-09-23 (time: 2.70 s tot,  4.9 ms/speech)
# Loaded  831 speeches from 2024-09-24 (time: 3.60 s tot,  4.3 ms/speech)
# Loaded  813 speeches from 2024-09-25 (time: 6.07 s tot,  7.5 ms/speech)
# Loaded   32 speeches from 2024-09-27 (time: 0.45 s tot, 14.0 ms/speech)
# Loaded   70 speeches from 2024-10-01 (time: 0.69 s tot,  9.9 ms/speech)
# Loaded   45 speeches from 2024-10-04 (time: 0.62 s tot, 13.8 ms/speech)
# Loaded   15 speeches from 2024-10-08 (time: 0.33 s tot, 22.2 ms/speech)
# Loaded   32 speeches from 2024-10-11 (time: 0.64 s tot, 19.9 ms/speech)
# Loaded   15 speeches from 2024-10-15 (time: 0.25 s tot, 16.6 ms/speech)
# Loaded   75 speeches from 2024-10-18 (time: 1.11 s tot, 14.8 ms/speech)
# Loaded   50 speeches from 2024-10-22 (time: 0.74 s tot, 14.7 ms/speech)
# Loaded   68 speeches from 2024-10-25 (time: 0.91 s tot, 13.3 ms/speech)
# Loaded   39 speeches from 2024-10-29 (time: 0.63 s tot, 16.2 ms/speech)
# Loaded   53 speeches from 2024-11-01 (time: 0.66 s tot, 12.5 ms/speech)
# Loaded    2 speeches from 2024-11-04 (time: 0.04 s tot, 18.6 ms/speech)
# Loaded   21 speeches from 2024-11-05 (time: 0.29 s tot, 13.8 ms/speech)
# Loaded    2 speeches from 2024-11-06 (time: 0.05 s tot, 23.8 ms/speech)
# Loaded   24 speeches from 2024-11-08 (time: 0.46 s tot, 19.3 ms/speech)
# Loaded  332 speeches from 2024-11-12 (time: 2.35 s tot,  7.1 ms/speech)
# Loaded  198 speeches from 2024-11-13 (time: 1.71 s tot,  8.6 ms/speech)
# Loaded  313 speeches from 2024-11-14 (time: 1.03 s tot,  3.3 ms/speech)
# Loaded   83 speeches from 2024-11-15 (time: 0.64 s tot,  7.7 ms/speech)
# Loaded  430 speeches from 2024-11-18 (time: 3.14 s tot,  7.3 ms/speech)
# Loaded  338 speeches from 2024-11-19 (time: 2.90 s tot,  8.6 ms/speech)
# Loaded  569 speeches from 2024-11-20 (time: 3.57 s tot,  6.3 ms/speech)
# Loaded  297 speeches from 2024-11-21 (time: 3.48 s tot, 11.7 ms/speech)
# Loaded   19 speeches from 2024-11-22 (time: 0.38 s tot, 20.2 ms/speech)
# Loaded   15 speeches from 2024-11-26 (time: 0.44 s tot, 29.3 ms/speech)
# Loaded    9 speeches from 2024-11-29 (time: 0.41 s tot, 45.9 ms/speech)
# Loaded  109 speeches from 2024-12-02 (time: 0.66 s tot,  6.0 ms/speech)
# Loaded  474 speeches from 2024-12-03 (time: 2.70 s tot,  5.7 ms/speech)
# Loaded  729 speeches from 2024-12-04 (time: 3.17 s tot,  4.4 ms/speech)
# Loaded  352 speeches from 2024-12-05 (time: 2.51 s tot,  7.1 ms/speech)
# Loaded  119 speeches from 2024-12-06 (time: 0.56 s tot,  4.7 ms/speech)
# Loaded  259 speeches from 2024-12-09 (time: 0.80 s tot,  3.1 ms/speech)
# Loaded  516 speeches from 2024-12-10 (time: 3.54 s tot,  6.9 ms/speech)
# Loaded  405 speeches from 2024-12-11 (time: 2.91 s tot,  7.2 ms/speech)
# Loaded  313 speeches from 2024-12-12 (time: 2.10 s tot,  6.7 ms/speech)
# Loaded  550 speeches from 2024-12-16 (time: 2.87 s tot,  5.2 ms/speech)
# Loaded  739 speeches from 2024-12-17 (time: 2.95 s tot,  4.0 ms/speech)
# Loaded  540 speeches from 2024-12-18 (time: 3.98 s tot,  7.4 ms/speech)
# Loaded  305 speeches from 2024-12-19 (time: 3.12 s tot, 10.2 ms/speech)
# Loaded  539 speeches from 2024-12-20 (time: 2.81 s tot,  5.2 ms/speech)
# Loaded    2 speeches from 2024-12-23 (time: 0.03 s tot, 17.1 ms/speech)
# Loaded   11 speeches from 2024-12-24 (time: 0.16 s tot, 14.6 ms/speech)
# Loaded    2 speeches from 2024-12-26 (time: 0.03 s tot, 15.2 ms/speech)
# Loaded    4 speeches from 2024-12-27 (time: 0.13 s tot, 33.7 ms/speech)
# Loaded    2 speeches from 2024-12-30 (time: 0.04 s tot, 20.2 ms/speech)
# Loaded    9 speeches from 2024-12-31 (time: 0.26 s tot, 29.3 ms/speech)

# %%
# Create dataframe
if len(data):
    df = pd.DataFrame.from_dict(data).astype({'speech_id'        : str,
                                              'speech'           : str, 
                                              'chamber'          : str, 
                                              'is_extension'     : bool,
                                              'date'             : 'datetime64[ns]', 
                                              'speaker'          : str,
                                              'speaker_bioguide' : str,
                                              'vol'              : int,
                                              'num'              : int,
                                              'congress_num'     : int,
                                              'pages'            : str, 
                                              'doc_title'        : str, 
                                              'title'            : str})
    del data
    if DO_SAVE:
       df.to_csv('./crec2023_2024.csv', index=False)
else:
    print("No data found!")

# %%
parsed_df = df.copy()

# %%
print("Rows:", len(parsed_df))
print("Extensions:", parsed_df["is_extension"].sum())
parsed_df
# Out:
# Rows: 98187
# Extensions: 8660
#                              speech_id  \
# 0        CREC-2023-01-04-pt1-PgH17-2-0
# 1        CREC-2023-01-04-pt1-PgH17-2-1
# 2        CREC-2023-01-04-pt1-PgH17-2-5
# 3          CREC-2023-01-04-pt1-PgH17-1
# 4          CREC-2023-01-04-pt1-PgH17-2
# ...                                ...
# 98182    CREC-2024-12-31-pt1-PgE1336-3
# 98183  CREC-2024-12-31-pt1-PgH7429-4-0
# 98184  CREC-2024-12-31-pt1-PgH7429-5-0
# 98185  CREC-2024-12-31-pt1-PgH7430-3-2
# 98186    CREC-2024-12-31-pt1-PgH7431-0
#
#                                                   speech chamber  \
# 0      Madam Clerk, I move that the House do now adjo...       H
# 1      The question is on the motion of the gentleman...       H
# 2       Madam Clerk, on that I demand the yeas and nays.       H
# 3      The Chair has examined the Journal of the last...       H
# 4      Representatives-elect are invited to join in t...       H
# ...                                                  ...     ...
# 98182  Mr. Speaker, I rise to honor Mr. Marvin Dennis...       H
# 98183  Pursuant to section 3(z) of House Resolution 5...       H
# 98184  The Chair will lead the House in the Pledge of...       H
# 98185   Without objection, the resolution was agreed to.       H
# 98186  Pursuant to section 3(z) of House Resolution 5...       H
#
#        is_extension       date                  speaker speaker_bioguide  vol  \
# 0             False 2023-01-04                 Mr. COLE          C001053  169
# 1             False 2023-01-04                The CLERK             None  169
# 2             False 2023-01-04              Mr. AGUILAR          A000371  169
# 3             False 2023-01-04                The CLERK             None  169
# 4             False 2023-01-04                The CLERK             None  169
# ...             ...        ...                      ...              ...  ...
# 98182          True 2024-12-31             Mr. GRIFFITH          G000568  170
# 98183         False 2024-12-31  The SPEAKER pro tempore             None  170
# 98184         False 2024-12-31  The SPEAKER pro tempore             None  170
# 98185         False 2024-12-31  The SPEAKER pro tempore             None  170
# 98186         False 2024-12-31  The SPEAKER pro tempore             None  170
#
#        num  congress_num        pages  \
# 0        3           118      H17-H18
# 1        3           118      H17-H18
# 2        3           118      H17-H18
# 3        3           118          H17
# 4        3           118          H17
# ...    ...           ...          ...
# 98182  196           118        E1336
# 98183  196           118        H7429
# 98184  196           118        H7429
# 98185  196           118        H7430
# 98186  196           118  H7431-H7432
#
#                                                doc_title  \
# 0                                      MOTION TO ADJOURN
# 1                                      MOTION TO ADJOURN
# 2                                      MOTION TO ADJOURN
# 3                                                 Senate
# 4                                                 Senate
# ...                                                  ...
# 98182            HONORING THE LIFE OF MARVIN REASER, Jr.
# 98183                                        THE JOURNAL
# 98184                               PLEDGE OF ALLEGIANCE
# 98185  EXPRESSING THE PROFOUND REGRET AND SORROW OF T...
# 98186                                        ADJOURNMENT
#
#                                                    title
# 0                                      MOTION TO ADJOURN
# 1                                      MOTION TO ADJOURN
# 2                                      MOTION TO ADJOURN
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 98182                                               None
# 98183                                        THE JOURNAL
# 98184                               PLEDGE OF ALLEGIANCE
# 98185  EXPRESSING THE PROFOUND REGRET AND SORROW OF T...
# 98186                                        ADJOURNMENT
#
# [98187 rows x 13 columns]
